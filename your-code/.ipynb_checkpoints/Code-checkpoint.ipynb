# %% [markdown]
# ## Project ##

# %% [markdown]
# Based on the initial state of the data set Shark Attack, it is clear that there is missing data according to the demographic information, details and description of the cases reported in it.

# %% [markdown]
# Importing the data is the first step in any data science project, that is why I will import the CSV file into Python using read_csv() from pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sharks_df = pd.read_csv("/Users/CB/Ironhack/Projects/pandas-project/attacks.csv", encoding="latin")

# %% [markdown]
# Note: Character encoding refers to the way characters are represented as a series of bytes. For further explenation chech the following link: https://stackoverflow.com/tags/character-encoding/info

# %%
sharks_df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %% [markdown]
# It seems that there is missing information in this data frame and before starting with the analysis, we must complete all the records. First, It is reasonable to find the type of data provided and then evaluate how to get the gender and age of each person attacked by a single of a group of sharks to clearly identify them.

# %%
T = sharks_df.dtypes.reset_index()
T
# Out:
#                      index        0
# 0              Case Number   object
# 1                     Date   object
# 2                     Year  float64
# 3                     Type   object
# 4                  Country   object
# 5                     Area   object
# 6                 Location   object
# 7                 Activity   object
# 8                     Name   object
# 9                     Sex    object
# 10                     Age   object
# 11                  Injury   object
# 12             Fatal (Y/N)   object
# 13                    Time   object
# 14                Species    object
# 15  Investigator or Source   object
# 16                     pdf   object
# 17            href formula   object
# 18                    href   object
# 19           Case Number.1   object
# 20           Case Number.2   object
# 21          original order  float64
# 22             Unnamed: 22   object
# 23             Unnamed: 23   object

# %% [markdown]
# Knowing that the values in the column Sex are objects, guarantee us that we can actually manupulate tha data contained in it. Nevertheless, as the values in the column Age are not either Integers (int64) or Floats (float64), our first priority is to transform the data into values.

# %%
sharks_df['Age'] = pd.to_numeric(sharks_df['Age'], errors='coerce', downcast = "integer")

# %%
sharks_df['Age']
# Out:
# 0        57.0
# 1        11.0
# 2        48.0
# 3         NaN
# 4         NaN
#          ...
# 25718     NaN
# 25719     NaN
# 25720     NaN
# 25721     NaN
# 25722     NaN
# Name: Age, Length: 25723, dtype: float64

# %% [markdown]
# Now, we can manipulate the data contained in the column Age. For doing so, it is crusial to find the total number of avaiable data whitin the records that contains verified information in the dataframe.

# %%
len(sharks_df.Age)
# Out:
# 25723

# %%
sum(sharks_df.Age.isna())
# Out:
# 22354

# %% [markdown]
# It seems that 22354 out of the 25723 records do not contain any information regarding the age of the person involved in the attacked reported.

# %%
sharks_df.rename(columns={"Sex ":"Sex"}, inplace=True)

# %%
len(sharks_df.Sex)
# Out:
# 25723

# %%
sum(sharks_df.Sex.isna())
# Out:
# 19986

# %% [markdown]
# After making sure the column Sex in the DataFrame was labeled correctly, it is clear that 19986 out of the 25723 records are empty.

# %% [markdown]
# ## Demographics

# %% [markdown]
# In order to display the available data in the DataFrame, it is clear that we should evaluate the columns Sex and Age to obtain insights about the attacks

# %%
sex_and_age = sharks_df.loc[:, ["Sex", "Age"]].copy()

# %%
sex_and_age
# Out:
#        Sex   Age
# 0        F  57.0
# 1        F  11.0
# 2        M  48.0
# 3        M   NaN
# 4        M   NaN
# ...    ...   ...
# 25718  NaN   NaN
# 25719  NaN   NaN
# 25720  NaN   NaN
# 25721  NaN   NaN
# 25722  NaN   NaN
#
# [25723 rows x 2 columns]

# %%
sex_and_age.groupby("Sex").describe()
# Out:
#         Age
#       count       mean        std   min   25%   50%   75%   max
# Sex
# .       0.0        NaN        NaN   NaN   NaN   NaN   NaN   NaN
# F     443.0  26.860045  16.431079   1.0  14.0  21.0  38.0  77.0
# M    2892.0  27.482019  13.493071   1.0  17.0  24.0  35.0  87.0
# M       1.0  42.000000        NaN  42.0  42.0  42.0  42.0  42.0
# N       0.0        NaN        NaN   NaN   NaN   NaN   NaN   NaN
# lli     1.0  38.000000        NaN  38.0  38.0  38.0  38.0  38.0

# %% [markdown]
# As shown before, there are records of attacks not included in the table obtained, due to the inability of having both values (Sex and Age) for the demographic analysis. If we recall the total number of records that have at least one value for Sex but not not Age, then it is concibable this number of records available.

# %%
sum((sex_and_age.Sex == "F") & (sex_and_age.Age.isna()))
# Out:
# 194

# %%
sum((sex_and_age.Sex == "M") & (sex_and_age.Age.isna()))
# Out:
# 2203

# %%
sex_and_age.Sex.value_counts()
# Out:
# M      5094
# F       637
# M         2
# N         2
# .         1
# lli       1
# Name: Sex, dtype: int64

# %%
set(sex_and_age.Sex.values)
# Out:
# {'.', 'F', 'M', 'M ', 'N', 'lli', nan}

# %%
sex_and_age.loc[sex_and_age.Sex == "M ", "Sex"] = "M"
sex_and_age.loc[sex_and_age.Sex == ".", "Sex"] = "NA"
sex_and_age.loc[sex_and_age.Sex == "N", "Sex"] = "NA"
sex_and_age.loc[sex_and_age.Sex == "lli", "Sex"] = "NA"
sex_and_age.loc[sex_and_age.Sex.isna(), "Sex"] = "NA"

# %%
Table_1 = sex_and_age.groupby("Sex").describe()
Table_1
# Out:
#         Age
#       count       mean        std  min   25%   50%   75%   max
# Sex
# F     443.0  26.860045  16.431079  1.0  14.0  21.0  38.0  77.0
# M    2893.0  27.487038  13.493438  1.0  17.0  24.0  35.0  87.0
# NA     33.0  23.787879  12.494393  3.0  16.0  20.0  28.0  60.0

# %% [markdown]
# Now that we have classificated the most related values that weren't aggregated in the categorized acceptable values (F stands for Female, M for Male and NA for Not Accepted) in the first table, it is time to start obtaining some insights about the classified data.

# %%
sex_and_age.loc[sex_and_age.Sex!="NA", :].hist(column="Age", by="Sex", grid=False, figsize=(12, 6));

# %% [markdown]
# Once compared the number of attacts segmented by sex, it is evident that the most affected people is considerably young in each group as they have had suffered the ferocity of the sharks when doing some of the activities described in the initial data set.

# %%
f_age = sex_and_age.loc[sex_and_age.Sex=='F',:].hist(column='Age', grid=False, figsize=(12,6))

# %%
Table_1.loc["F", :]
# Out:
# Age  count    443.000000
#      mean      26.860045
#      std       16.431079
#      min        1.000000
#      25%       14.000000
#      50%       21.000000
#      75%       38.000000
#      max       77.000000
# Name: F, dtype: float64

# %%
m_age = sex_and_age.loc[sex_and_age.Sex=='M',:].hist(column='Age', grid=False, figsize=(12,6))

# %%
Table_1.loc["M", :]
# Out:
# Age  count    2893.000000
#      mean       27.487038
#      std        13.493438
#      min         1.000000
#      25%        17.000000
#      50%        24.000000
#      75%        35.000000
#      max        87.000000
# Name: M, dtype: float64

# %% [markdown]
# ## Space-time statistics

# %% [markdown]
# Before diving into the data, it is important to point out that for now we will focus on the year and the country where the attack took place to extract some insights about the records available.

# %%
space_and_time = sharks_df.loc[:, ["Year", "Country"]]
space_and_time
# Out:
#          Year    Country
# 0      2018.0        USA
# 1      2018.0        USA
# 2      2018.0        USA
# 3      2018.0  AUSTRALIA
# 4      2018.0     MEXICO
# ...       ...        ...
# 25718     NaN        NaN
# 25719     NaN        NaN
# 25720     NaN        NaN
# 25721     NaN        NaN
# 25722     NaN        NaN
#
# [25723 rows x 2 columns]

# %%
space_and_time.groupby("Country").describe()
# Out:
#                    Year                                                   \
#                   count         mean         std     min     25%     50%
# Country
#  PHILIPPINES        1.0  1944.000000         NaN  1944.0  1944.0  1944.0
#  TONGA              3.0  2002.666667    2.309401  2000.0  2002.0  2004.0
# ADMIRALTY ISLANDS   1.0  1962.000000         NaN  1962.0  1962.0  1962.0
# AFRICA              1.0  1846.000000         NaN  1846.0  1846.0  1846.0
# ALGERIA             1.0  1844.000000         NaN  1844.0  1844.0  1844.0
# ...                 ...          ...         ...     ...     ...     ...
# VIETNAM            15.0  1720.466667  699.949474     0.0  1921.5  2009.0
# WEST INDIES         2.0  1869.000000   41.012193  1840.0  1854.5  1869.0
# WESTERN SAMOA       1.0  1972.000000         NaN  1972.0  1972.0  1972.0
# YEMEN               2.0  1981.000000   36.769553  1955.0  1968.0  1981.0
# YEMEN               7.0  1899.000000    3.559026  1895.0  1897.5  1898.0
#
#
# ...

# %%
space_and_time.Country.value_counts()
# Out:
# USA                     2229
# AUSTRALIA               1338
# SOUTH AFRICA             579
# PAPUA NEW GUINEA         134
# NEW ZEALAND              128
#                         ...
# OCEAN                      1
# ARUBA                      1
# JAVA                       1
# PARAGUAY                   1
# NORTHERN ARABIAN SEA       1
# Name: Country, Length: 212, dtype: int64

# %%
set(space_and_time.Country.values)
# Out:
# {' PHILIPPINES',
#  ' TONGA',
#  'ADMIRALTY ISLANDS',
#  'AFRICA',
#  'ALGERIA',
#  'AMERICAN SAMOA',
#  'ANDAMAN / NICOBAR ISLANDAS',
#  'ANDAMAN ISLANDS',
#  'ANGOLA',
#  'ANTIGUA',
#  'ARGENTINA',
#  'ARUBA',
#  'ASIA?',
#  'ATLANTIC OCEAN',
#  'AUSTRALIA',
#  'AZORES',
#  'BAHAMAS',
#  'BAHREIN',
#  'BANGLADESH',
#  'BARBADOS',
#  'BAY OF BENGAL',
#  'BELIZE',
#  'BERMUDA',
#  'BRAZIL',
#  'BRITISH ISLES',
#  'BRITISH NEW GUINEA',
#  'BRITISH VIRGIN ISLANDS',
#  'BRITISH WEST INDIES',
#  'BURMA',
#  'Between PORTUGAL & INDIA',
#  'CANADA',
#  'CAPE VERDE',
#  'CARIBBEAN SEA',
#  'CAYMAN ISLANDS',
#  'CENTRAL PACIFIC',
#  'CEYLON',
#  'CEYLON (SRI LANKA)',
#  'CHILE',
#  'CHINA',
#  'COLUMBIA',
#  'COMOROS',
#  'COOK ISLANDS',
#  'COSTA RICA',
#  'CRETE',
#  'CROATIA',
#  'CUBA',
#  'CURACAO',
#  'CYPRUS',
#  'Coast of AFRICA',
#  'DIEGO GARCIA',
#  'DJIBOUTI',
#  'DOMINICAN REPUBLIC',
#  'ECUADOR',
#  'EGYPT',
#  'EGYPT ',
#  'EGYPT / ISRAEL',
#  'EL SALVADOR',
#  'ENGLAND',
# ...

# %% [markdown]
# As can be seen, there are some records where the country isn't a valid one. It is crucial to remove the incorrect data to extract the real picture of the places where there were more reported cases. This is why we have created a countries list to compare the respective column of the space_and_time DataFrame and make sure only the ones with accurate data are meant to remain.

# %%
countries_str = """Afghanistan
Albania
Algeria
Andorra
Angola
Antigua and Barbuda
Argentina
Armenia
Australia
Austria
Azerbaijan
Bahamas
Bahrain
Bangladesh
Barbados
Belarus
Belgium
Belize
Benin
Bhutan
Bolivia
Bosnia and Herzegovina
Botswana
Brazil
Brunei
Bulgaria
Burkina Faso
Burundi
Cabo Verde
Cambodia
Cameroon
Canada
Central African Republic
Chad
Chile
China
Colombia
Comoros
Congo
Costa Rica
Croatia
Cuba
Cyprus
Czech Republic (Czechia)
Côte d'Ivoire
Denmark
Djibouti
Dominica
Dominican Republic
DR Congo
Ecuador
Egypt
El Salvador
Equatorial Guinea
Eritrea
Estonia
Eswatini
Ethiopia
Fiji
Finland
France
Gabon
Gambia
Georgia
Germany
Ghana
Greece
Grenada
Guatemala
Guinea
Guinea-Bissau
Guyana
Haiti
Holy See
Honduras
Hungary
Iceland
India
Indonesia
Iran
Iraq
Ireland
Israel
Italy
Jamaica
Japan
Jordan
Kazakhstan
Kenya
Kiribati
Kuwait
Kyrgyzstan
Laos
Latvia
Lebanon
Lesotho
Liberia
Libya
Liechtenstein
Lithuania
Luxembourg
Madagascar
Malawi
Malaysia
Maldives
Mali
Malta
Marshall Islands
Mauritania
Mauritius
Mexico
Micronesia
Moldova
Monaco
Mongolia
Montenegro
Morocco
Mozambique
Myanmar
Namibia
Nauru
Nepal
Netherlands
New Zealand
Nicaragua
Niger
Nigeria
North Korea
North Macedonia
Norway
Oman
Pakistan
Palau
Panama
Papua New Guinea
Paraguay
Peru
Philippines
Poland
Portugal
Qatar
Romania
Russia
Rwanda
Saint Kitts & Nevis
Saint Lucia
Samoa
San Marino
Sao Tome & Principe
Saudi Arabia
Senegal
Serbia
Seychelles
Sierra Leone
Singapore
Slovakia
Slovenia
Solomon Islands
Somalia
South Africa
South Korea
South Sudan
Spain
Sri Lanka
St. Vincent & Grenadines
State of Palestine
Sudan
Suriname
Sweden
Switzerland
Syria
Tajikistan
Tanzania
Thailand
Timor-Leste
Togo
Tonga
Trinidad and Tobago 
Tunisia
Turkey
Turkmenistan
Tuvalu
Uganda
Ukraine
United Arab Emirates
UAE
United Kingdom
UK
United States
USA
US
Uruguay
Uzbekistan
Vanuatu
Venezuela
Vietnam
Yemen
Zambia
Zimbabwe"""

# %%
countries = countries_str.split("\n")

# %%
countries = [x.upper() for x in countries]

# %%
s_and_t_real = space_and_time.loc[space_and_time.Country.map(lambda x: x in countries), :]
s_and_t_real
# Out:
#         Year    Country
# 0     2018.0        USA
# 1     2018.0        USA
# 2     2018.0        USA
# 3     2018.0  AUSTRALIA
# 4     2018.0     MEXICO
# ...      ...        ...
# 6296     0.0  AUSTRALIA
# 6297     0.0  AUSTRALIA
# 6298     0.0  AUSTRALIA
# 6299     0.0        USA
# 6300     0.0     PANAMA
#
# [5787 rows x 2 columns]

# %% [markdown]
# Now, it is time to select a specific period to provide meaningful results regarding the validated data. Let's say we want to know the most affected countries by shark attacks in the current century.

# %%
v_years = range(2000, 2019)

# %%
yeah = s_and_t_real.loc[s_and_t_real.Year.map(lambda x: x in v_years), :]
yeah
# Out:
#         Year       Country
# 0     2018.0           USA
# 1     2018.0           USA
# 2     2018.0           USA
# 3     2018.0     AUSTRALIA
# 4     2018.0        MEXICO
# ...      ...           ...
# 2072  2000.0  SOUTH AFRICA
# 2074  2000.0   NEW ZEALAND
# 2075  2000.0     AUSTRALIA
# 2077  2000.0      THAILAND
# 2078  2000.0           USA
#
# [1944 rows x 2 columns]

# %%
yeah.hist("Country", by="Year", figsize=(25, 30));

# %% [markdown]
# Each graph exposes the countries where there were more reported cases in each specific year from 2000 to 2018 which is the most recent year we have records.
